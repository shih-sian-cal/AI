# %% [markdown]
# <a href="https://colab.research.google.com/github/shhuangmust/AI/blob/110-2/5.keras_CNN_Cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
model=Sequential()
model.add(Conv2D(filters=64, kernel_size=(5, 5), input_shape=(32, 32, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=(5, 5), activation='relu'))
model.add(Conv2D(filters=128, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
model.summary()
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        4864
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        102464
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         204928
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)         409728
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 10)                5130
#
# =================================================================
# Total params: 727,114
# Trainable params: 727,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
cifar10=keras.datasets.cifar10
(train_data, train_label), (test_data, test_label) = cifar10.load_data()
train_label_original=train_label
train_label = keras.utils.to_categorical(train_label)
test_label = keras.utils.to_categorical(test_label)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step
# 170508288/170498071 [==============================] - 13s 0us/step

# %%
import matplotlib.pyplot as plt
category=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
plt.imshow(train_data[0])
plt.title(category[int(train_label_original[0])])
plt.show()
print(train_label_original[0])
# Out:
# [6]

# %%
train_history=model.fit(train_data,train_label,epochs=30,batch_size=512)
# Out:
# Epoch 1/30
# 98/98 [==============================] - 17s 52ms/step - loss: 12.4744 - accuracy: 0.1801
# Epoch 2/30
# 98/98 [==============================] - 4s 45ms/step - loss: 2.3293 - accuracy: 0.2111
# Epoch 3/30
# 98/98 [==============================] - 4s 45ms/step - loss: 2.0047 - accuracy: 0.3036
# Epoch 4/30
# 98/98 [==============================] - 4s 45ms/step - loss: 1.9191 - accuracy: 0.3487
# Epoch 5/30
# 98/98 [==============================] - 4s 45ms/step - loss: 1.8798 - accuracy: 0.3775
# Epoch 6/30
# 98/98 [==============================] - 4s 46ms/step - loss: 1.6042 - accuracy: 0.4497
# Epoch 7/30
# 98/98 [==============================] - 4s 46ms/step - loss: 1.4991 - accuracy: 0.4887
# Epoch 8/30
# 98/98 [==============================] - 5s 46ms/step - loss: 1.3889 - accuracy: 0.5363
# Epoch 9/30
# 98/98 [==============================] - 5s 46ms/step - loss: 1.2179 - accuracy: 0.5844
# Epoch 10/30
# 98/98 [==============================] - 5s 47ms/step - loss: 1.0859 - accuracy: 0.6271
# Epoch 11/30
# 98/98 [==============================] - 5s 47ms/step - loss: 1.0579 - accuracy: 0.6427
# Epoch 12/30
# 98/98 [==============================] - 5s 47ms/step - loss: 0.8765 - accuracy: 0.7004
# Epoch 13/30
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7603 - accuracy: 0.7402
# Epoch 14/30
# 98/98 [==============================] - 5s 47ms/step - loss: 0.6882 - accuracy: 0.7702
# Epoch 15/30
# 98/98 [==============================] - 5s 47ms/step - loss: 0.5893 - accuracy: 0.8013
# Epoch 16/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.4968 - accuracy: 0.8307
# Epoch 17/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.4447 - accuracy: 0.8491
# Epoch 18/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.3868 - accuracy: 0.8705
# Epoch 19/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.3277 - accuracy: 0.8912
# Epoch 20/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.3167 - accuracy: 0.8970
# Epoch 21/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2781 - accuracy: 0.9124
# Epoch 22/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2728 - accuracy: 0.9154
# Epoch 23/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2475 - accuracy: 0.9219
# Epoch 24/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2369 - accuracy: 0.9263
# Epoch 25/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2427 - accuracy: 0.9284
# Epoch 26/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2206 - accuracy: 0.9339
# Epoch 27/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2300 - accuracy: 0.9348
# Epoch 28/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2102 - accuracy: 0.9398
# Epoch 29/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2325 - accuracy: 0.9380
# Epoch 30/30
# 98/98 [==============================] - 5s 48ms/step - loss: 0.2047 - accuracy: 0.9425

# %%
score=model.evaluate(test_data, test_label)
print(score[1])
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 3.7823 - accuracy: 0.6023
# 0.6022999882698059

# %%
#繪製正確性與損失歷史圖
import matplotlib.pyplot as plt
import numpy as np

def show_train_history(train_history, train):
    plt.plot(train_history.history[train])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train'], loc='center right')
    plt.show()

show_train_history(train_history, 'accuracy')
show_train_history(train_history, 'loss')
